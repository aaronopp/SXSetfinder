# %%
from BeautifulSoup import BeautifulSoup

# %%
html = '<div class=“text-center text-tiny”>Mar 17, 2018<br/>9:00pm – 9:40pm</div>'

# %%
soup = BeautifulSoup(html)
all_text = ''.join(soup.findAll(text=True))

# %%
all_text
# Out:
# u'Mar 17, 20189:00pm \u2013 9:40pm'

# %%
from flask import render_template, flash, redirect, url_for
# from app import app
# from app.forms import LoginForm, SpotifyForm

import sys
import spotipy
import spotipy.util as util
import time as time

import webbrowser
from server import block_until_token
from utils import *

import urllib, json
import csv
import pandas as pd

url = "http://smarterplaylists.playlistmachinery.com/frog/path";


raw_csv =  pd.read_csv('/Users/aaronopp/Desktop/GOOD_MEDIA/SXSetFinder/app/events.csv')

# %%
raw_csv
# Out:
#                                          artistname  \
# 0                                               070
# 1                                    16 the Olympus
# 2                   1982 (diecinueve ochenta y dos)
# 3                   1982 (diecinueve ochenta y dos)
# 4                                            1kPhew
# 5                                            1Playy
# 6     20 Somethin' Band/Tenth Child Inc. House Band
# 7                                             24Hrs
# 8                                             24Hrs
# 9                                    3 Hand Stephen
# 10                                              5-D
# 11                                             5ive
# 12                                           6Blocc
# 13                                           90 One
# 14                                   Abhi The Nomad
# 15                                       Abisha Uhl
# 16                                         ABSTRACT
# 17                                         ABSTRACT
# 18                                     The Academic
# 19                                  The Accidentals
# 20                                  The Accidentals
# 21                                       Ace Harper
# 22                                           A.CHAL
# 23                                         Acid Dad
# 24                                         Acid Dad
# 25                                 Acid House Ragas
# 26                                      Acid Tongue
# 27                                      Acid Tongue
# 28                                        AC Smitty
# 29                                   Action Bronson
# ...                                             ...
# 2528                                    Young Lyric
# 2529                                   Young & Sick
# 2530                                   Young & Sick
# 2531                                 The Young Step
# 2532                                        Yultron
# 2533                                     Yung Pinch
# 2534                                     Yung Pinch
# 2535                                     Yung Ruler
# 2536                                      Yung Tory
# 2537                                      Yxng Bane
# 2538                                      Yxng Bane
# 2539                                      Yxng Bane
# 2540                   Zach Blair (of Rise Against)
# 2541                                      Zack Keim
# 2542                                  Zac Wilkerson
# 2543                                 Zara McFarlane
# 2544                                       Zaytoven
# 2545                                        Zenizen
# 2546                               The Zephyr Bones
# 2547                               The Zephyr Bones
# 2548                               The Zephyr Bones
# 2549                                     Zero Balas
# 2550                                     Zero Balas
# 2551                                       Ziibiwan
# 2552                           ZIllaKami x SOS Mula
# 2553                                    Zoey Dollaz
# 2554                                    Zoey Dollaz
# 2555                               Zombies in Miami
# 2556                                           Zuli
# 2557                                           Zuli
#
#                                          artistURL           day starttime  \
# 0     https://schedule.sxsw.com/2018/artists/23352           NaN      None
# 1     https://schedule.sxsw.com/2018/artists/18953  Mar 17, 2018   8:00pm
# 2     https://schedule.sxsw.com/2018/artists/18148  Mar 14, 2018   9:10pm
# 3     https://schedule.sxsw.com/2018/artists/18148  Mar 16, 2018  10:00pm
# 4     https://schedule.sxsw.com/2018/artists/23658  Mar 16, 2018   9:25pm
# 5     https://schedule.sxsw.com/2018/artists/23747  Mar 14, 2018   9:00pm
# 6     https://schedule.sxsw.com/2018/artists/23089  Mar 17, 2018   8:00pm
# 7     https://schedule.sxsw.com/2018/artists/23723  Mar 14, 2018  12:00am
# 8     https://schedule.sxsw.com/2018/artists/23723  Mar 13, 2018   1:00am
# 9     https://schedule.sxsw.com/2018/artists/20007  Mar 17, 2018   9:00pm
# 10    https://schedule.sxsw.com/2018/artists/23837  Mar 15, 2018      None
# 11    https://schedule.sxsw.com/2018/artists/23053  Mar 16, 2018  11:10pm
# 12    https://schedule.sxsw.com/2018/artists/23639  Mar 17, 2018  12:00am
# 13    https://schedule.sxsw.com/2018/artists/23174  Mar 17, 2018   9:45pm
# 14    https://schedule.sxsw.com/2018/artists/21019  Mar 16, 2018   7:30pm
# 15    https://schedule.sxsw.com/2018/artists/22555  Mar 17, 2018  10:45pm
# 16    https://schedule.sxsw.com/2018/artists/23441  Mar 15, 2018  10:00pm
# 17    https://schedule.sxsw.com/2018/artists/23441  Mar 15, 2018  11:15pm
# 18    https://schedule.sxsw.com/2018/artists/22650  Mar 13, 2018   1:00am
# 19    https://schedule.sxsw.com/2018/artists/22984  Mar 16, 2018   8:00pm
# 20    https://schedule.sxsw.com/2018/artists/22984  Mar 13, 2018  11:00pm
# 21    https://schedule.sxsw.com/2018/artists/23546  Mar 17, 2018  10:00pm
# 22    https://schedule.sxsw.com/2018/artists/21565  Mar 15, 2018  10:00pm
# 23    https://schedule.sxsw.com/2018/artists/20475  Mar 15, 2018  11:00pm
# 24    https://schedule.sxsw.com/2018/artists/20475  Mar 14, 2018   1:25am
# 25    https://schedule.sxsw.com/2018/artists/22976  Mar 15, 2018   9:00pm
# 26    https://schedule.sxsw.com/2018/artists/18320  Mar 15, 2018  12:00am
# 27    https://schedule.sxsw.com/2018/artists/18320  Mar 16, 2018   1:00am
# 28    https://schedule.sxsw.com/2018/artists/19355  Mar 16, 2018  10:00pm
# 29    https://schedule.sxsw.com/2018/artists/23453  Mar 15, 2018  12:00am
# ...                                            ...           ...       ...
# 2528  https://schedule.sxsw.com/2018/artists/23660  Mar 16, 2018  11:55pm
# 2529  https://schedule.sxsw.com/2018/artists/22883  Mar 15, 2018  12:00am
# 2530  https://schedule.sxsw.com/2018/artists/22883  Mar 14, 2018   9:00pm
# 2531  https://schedule.sxsw.com/2018/artists/21309  Mar 15, 2018  12:00am
# 2532  https://schedule.sxsw.com/2018/artists/19858  Mar 14, 2018  11:00pm
# 2533  https://schedule.sxsw.com/2018/artists/23687  Mar 12, 2018   9:15pm
# 2534  https://schedule.sxsw.com/2018/artists/23687  Mar 13, 2018  12:00am
# 2535  https://schedule.sxsw.com/2018/artists/23709  Mar 16, 2018  11:15pm
# 2536  https://schedule.sxsw.com/2018/artists/23833  Mar 17, 2018  10:40pm
# 2537  https://schedule.sxsw.com/2018/artists/19885  Mar 15, 2018  11:25pm
# 2538  https://schedule.sxsw.com/2018/artists/19885  Mar 16, 2018  10:00pm
# 2539  https://schedule.sxsw.com/2018/artists/19885  Mar 16, 2018   8:45pm
# 2540  https://schedule.sxsw.com/2018/artists/23863  Mar 17, 2018      None
# 2541  https://schedule.sxsw.com/2018/artists/21579  Mar 15, 2018   8:00pm
# 2542  https://schedule.sxsw.com/2018/artists/23336  Mar 16, 2018  10:00pm
# 2543  https://schedule.sxsw.com/2018/artists/17636  Mar 14, 2018  11:00pm
# 2544  https://schedule.sxsw.com/2018/artists/23827           NaN      None
# 2545  https://schedule.sxsw.com/2018/artists/19262  Mar 13, 2018   8:20pm
# 2546  https://schedule.sxsw.com/2018/artists/19016  Mar 15, 2018   7:00pm
# 2547  https://schedule.sxsw.com/2018/artists/19016  Mar 14, 2018  10:00pm
# 2548  https://schedule.sxsw.com/2018/artists/19016  Mar 16, 2018  12:10am
# 2549  https://schedule.sxsw.com/2018/artists/22781  Mar 13, 2018  10:00pm
# 2550  https://schedule.sxsw.com/2018/artists/22781  Mar 16, 2018   1:15am
# 2551  https://schedule.sxsw.com/2018/artists/23384  Mar 17, 2018  10:00pm
# 2552  https://schedule.sxsw.com/2018/artists/23781  Mar 15, 2018   7:40pm
# 2553  https://schedule.sxsw.com/2018/artists/20159  Mar 16, 2018  10:30pm
# 2554  https://schedule.sxsw.com/2018/artists/20159  Mar 14, 2018  12:10am
# 2555  https://schedule.sxsw.com/2018/artists/23234  Mar 16, 2018   9:00pm
# 2556  https://schedule.sxsw.com/2018/artists/19820  Mar 13, 2018  11:20pm
# 2557  https://schedule.sxsw.com/2018/artists/19820  Mar 17, 2018  11:20pm
#
#        endtime                                venue           category
# 0          TBD                                  TBD      Hip Hop / Rap
# 1       8:40pm                        Elephant Room               Jazz
# 2       9:50pm                    Speakeasy Kabaret       Latin Indie
# 3      10:40pm                         The Townsend       Latin Indie
# 4       9:40pm                               Parish      Hip Hop / Rap
# 5       9:20pm               Cedar Street Courtyard      Hip Hop / Rap
# 6       8:20pm                     18th Over Austin      Hip Hop / Rap
# 7      12:20am               Cedar Street Courtyard      Hip Hop / Rap
# 8       1:30am                        Ironwood Hall      Hip Hop / Rap
# 9       9:40pm                      Stephen F's Bar          Americana
# 10         TBD                                  TBD      Hip Hop / Rap
# 11     11:25pm   University Avenue Church of Christ             Gospel
# 12      1:00am                            Barcelona                 DJ
# 13     10:15pm     Carver Museum Boyd Vance Theater      Hip Hop / Rap
# 14      8:00pm               Tap Room at The Market      Hip Hop / Rap
# 15     11:05pm               Tap Room at The Market               Rock
# 16     10:30pm                      Waller Ballroom                 DJ
# 17     12:00am                      Waller Ballroom                 DJ
# 18      1:50am                          The Main II               Rock
# 19      8:30pm                    Trinity Warehouse               Folk
# 20     11:40pm                     18th Over Austin               Folk
# 21     10:40pm                  Palm Door on Sabine         Electronic
# 22     10:30pm                    Trinity Warehouse              R & B
# 23     11:40pm                             Valhalla               Punk
# 24      1:50am                        Dirty Dog Bar               Punk
# 25      9:40pm              Hotel Vegas at Volstead         Electronic
# 26     12:40am                             Javelina               Rock
# 27      1:50am               The Sidewinder Outside               Rock
# 28     10:10pm                               Parish      Hip Hop / Rap
# 29     12:40am                             Banger's      Hip Hop / Rap
# ...        ...                                  ...                ...
# 2528   12:10am                 Maggie Mae's Rooftop      Hip Hop / Rap
# 2529   12:35am                  Palm Door on Sabine                Pop
# 2530    9:40pm                  Empire Control Room                Pop
# 2531   12:40am                         The Townsend               Rock
# 2532   11:55pm                        Container Bar                 DJ
# 2533    9:45pm                        Native Hostel      Hip Hop / Rap
# 2534   12:20am                        Ironwood Hall      Hip Hop / Rap
# 2535   11:30pm                 Maggie Mae's Rooftop      Hip Hop / Rap
# 2536   10:55pm                        Ironwood Hall      Hip Hop / Rap
# 2537   11:55pm                          The Main II      Hip Hop / Rap
# 2538   10:40pm  British Music Embassy @ Latitude 30      Hip Hop / Rap
# 2539    9:00pm               Cedar Street Courtyard      Hip Hop / Rap
# 2540       TBD                                  TBD                TBD
# 2541    8:40pm                             Lamberts               Folk
# 2542   10:40pm                            Saxon Pub  Singer Songwriter
# 2543   11:40pm                          The Main II               Jazz
# 2544       TBD                                  TBD      Hip Hop / Rap
# 2545    8:50pm               The Sidewinder Outside                Pop
# 2546    7:40pm              Hotel Vegas at Volstead               Rock
# 2547   10:40pm                             Bungalow               Rock
# 2548   12:40am              Hotel Vegas at Volstead               Rock
# 2549   10:40pm                 Maggie Mae's Rooftop       Latin Indie
# 2550    1:50am                    Speakeasy Kabaret       Latin Indie
# 2551   10:30pm                    Speakeasy Kabaret         Electronic
# 2552    7:55pm                              Stubb's      Hip Hop / Rap
# 2553   11:00pm                  Empire Control Room      Hip Hop / Rap
# 2554   12:30am                            Half Step      Hip Hop / Rap
# 2555    9:40pm                           Blackheart         Electronic
# 2556   12:00am                          Seven Grand               Rock
# 2557   12:00am                      Swan Dive Patio               Rock
#
# [2558 rows x 7 columns]

# %%
artist_list = raw_csv['artistname'].tolist()
artist_list_trimmed = []

# %%
artist_list
# Out:
# ['070',
#  '16 the Olympus',
#  '1982 (diecinueve ochenta y dos)',
#  '1982 (diecinueve ochenta y dos)',
#  '1kPhew',
#  '1Playy',
#  "20 Somethin' Band/Tenth Child Inc. House Band",
#  '24Hrs',
#  '24Hrs',
#  '3 Hand Stephen',
#  '5-D',
#  '5ive',
#  '6Blocc',
#  '90 One',
#  'Abhi The Nomad',
#  'Abisha Uhl',
#  'ABSTRACT',
#  'ABSTRACT',
#  'The Academic',
#  'The Accidentals',
#  'The Accidentals',
#  'Ace Harper',
#  'A.CHAL',
#  'Acid Dad',
#  'Acid Dad',
#  'Acid House Ragas',
#  'Acid Tongue',
#  'Acid Tongue',
#  'AC Smitty',
#  'Action Bronson',
#  'Adahzeh',
#  'Adam + Kizzie',
#  'Adam Torres',
#  'Adekunle Gold',
#  'Adekunle Gold',
#  'Adekunle Gold',
#  'Adrian Daniel',
#  'The Afroknotts',
#  'AHI',
#  'Aiming For Enrike',
#  'Aiming For Enrike',
#  'Ainsley Farrell',
#  'Aisha Badru',
#  'AJ',
#  'AJ DeGrasse',
#  'AJ Tracey',
#  'AJ Tracey',
#  'AKA',
#  'AKA',
#  'Akina Adderley & The Vintage Playboys',
#  'AkinSanya',
#  'Albert Hammond Jr',
#  'Albert Hammond Jr',
#  'Alec Michael',
#  'Alejandro Franco',
#  'Aleman',
#  'Alesia Lani',
#  'Alesia Lani',
#  'Alexalone',
#  'Alex Di Leo',
#  'Alex Rose',
#  'ALI AKA MIND',
#  'ALI AKA MIND',
#  'Alice Bag',
#  'Alice Ivy',
#  'Alice Phoebe Lou',
#  'Alice Phoebe Lou',
#  'Allman Brown',
#  'Allman Brown',
#  'Al Lover',
#  'Alsarah & the Nubatones',
#  'Alsarah & the Nubatones',
#  'Alvmni',
#  'Amanze',
#  'Amara La Negra',
#  'Amara La Negra',
#  'Amara La Negra',
#  'American Folk - Joe Purdy & Amber Rubarth ',
#  'American Grime',
#  'American Sharks',
#  'Amy Becker',
#  'Amy Becker',
#  'Amy O',
#  'Amy Shark',
#  'Amy Shark',
#  'Anastasia',
#  'Andrea Cruz',
#  'Andre Cymone',
#  'Andrew Applepie',
#  'Andrew Applepie',
#  'Andrew Parsons',
#  'Andrew Parsons',
#  'Andrew W.K.',
#  '...And You Will Know Us by the Trail of Dead',
#  'Anemone',
#  'Anemone',
#  'Anemone',
#  'Angel',
#  'Angel + Dren',
#  'ANGELZ',
#  'Annabelle Chairlegs',
#  'Anna Burch',
#  'Anna Burch',
#  'Annalise Azadian',
#  'Annalise Azadian',
#  'Anna McClellan',
#  'Anna Takeuchi',
#  'Anna Wise',
#  'Anna Wise',
#  'Annie Hart',
#  'Annie Hart',
#  'Ant Beale',
#  'Anthony Somebody of Quite Hype',
#  'Anti-Lilly',
#  'Antwoine Hill',
#  'Antytila',
#  'Ardalan',
#  'Ari',
#  'Arin Ray',
#  'Arin Ray',
#  'Ari Roar',
#  'Arlie',
#  'A-RON',
#  'Arrows to Fire',
#  'Ashley Henry Trio',
#  'Ashley Koett',
#  'Ashton Marton',
#  'A. Sinclair',
#  'A. Sinclair',
#  'Ask Carol',
#  'Astrolabio',
#  'Astrolabio',
#  'ATASH',
#  'A-Town GetDown',
#  'Attractions',
#  'Audio Push',
#  'Audio Push',
#  'August Eve',
#  'August Greene (Common / Robert Glasper / Karriem Riggins)',
#  'Austin Lanier',
#  'Austin Martin',
#  'Automelodi',
#  'Automelodi',
#  'Avatar Darko',
#  'Avelino',
#  'AveParadiso',
#  'Ayuma',
#  'Aztec Death',
#  'B1',
#  'Bad Gyal',
#  'Bad Gyal',
#  'Bad Moves',
#  'Bad Moves',
#  'Bad Pony',
#  'BADYOSHI',
#  'Ball Greezy',
#  'Bambara',
#  'Bamsworth',
#  'Bang Data',
#  'Barachi',
#  'Barbara Nesbitt',
#  'Barrie',
#  'Barrie',
#  'Bat Fangs',
#  'Bat Fangs',
#  'Bat Fangs',
#  'BAUM',
#  'BAUM',
#  'Baywaves',
#  'Baywaves',
#  'BbyMutha',
#  'BdotCroc',
#  'Beach Slang',
#  'Beams',
#  'Beating Heart',
#  'Beating Heart',
#  'BeatKing',
#  'BeatKing',
#  'Beat Root Revival',
#  'Bea Troxel',
#  'Becca Mancari',
#  'Bekon',
#  'Belako',
#  'Belau',
#  'Belle Adair',
#  'Ben Aqua',
#  'Ben Dickey',
#  'Benin City',
#  'Benin City',
#  'Benin City',
#  'Benji Lewis',
#  'Benji Lewis',
#  'Ben Kweller',
#  'Benyaro',
#  'Benyaro',
#  'Beshken',
#  'Bethlehem Steel',
#  'Betonkust',
#  'BETO y los Fairlanes',
#  'BETO y los Fairlanes',
#  'B-Hi',
#  'Bidi Bidi Banda',
#  'Bifannah',
#  'Bifannah',
#  'Big Bill',
#  'Big League',
#  'Big Lean',
#  'Big Ro',
#  'Big T',
#  'Big Tobz',
#  'Big White',
#  "Big Wy's Brass Band",
#  'Big Zuu',
#  'Big Zuu',
#  'Billa',
#  'BillieB',
#  'Billie Eilish',
#  'Billie Eilish',
#  'Billie Eilish',
#  'Billie Eilish',
#  'Billyracxx',
#  'Billy Strings',
#  'B.I.P.',
#  'Bipolaroid',
#  'Bishop Briggs',
#  'Bishop Gunn',
#  'The Bishops',
#  'Blackberries',
#  'Black Guayaba',
#  'Black Heart Saints',
#  'Blackillac',
#  'Black Pistol Fire',
#  'Black Prophet',
#  'Black Pumas',
#  'Blake',
#  'Blake Brown & The American Dust Choir',
#  'BLANG',
#  'Blessed',
#  'The Blind Suns',
#  'Blindur',
#  'Blonde Maze',
#  'Blue Lab Beats',
#  'Blue Water Highway',
#  'Blushing',
#  'Blvck Spvde',
#  'Blvck Spvde',
#  'Bobo Swae',
#  'BODEGA',
#  'BODEGA',
#  'Bodywash',
#  'Bodywash',
#  'Boggie',
#  'BOGL',
#  'Bohemian Betyars',
#  'Bohemian Betyars',
#  'Bombasta',
#  'BONES (UK)',
#  'Boniface',
#  'Boniface',
#  'Boniface',
#  'Boniface',
#  'Bonnie Whitmore & Her Band',
#  'Boogat',
#  'Boogat',
#  'Booher',
#  'BoomBaptist',
#  'Boombox Cartel',
#  'BOOMS Y CLAPS',
#  'Born Gifted',
#  'Boss Street Brass Band',
#  'Boy Harsher',
#  'BOYO',
#  'BOYTOY',
#  'BOYTOY',
#  'BOYTOY',
#  'BP Valenzuela',
#  'BRAINWAVVE',
#  'Branjae',
#  'Breakfast Muff',
#  'Breakfast Muff',
#  'Breaking Forms',
#  'Breaking Forms',
#  'Breakout',
#  'Breanna Barbara',
#  'Brent Cowles',
#  'Brent Tactic',
#  'Bre-Z',
#  'Brian Merrill',
#  'Brian Pounds',
#  'The Bright Light Social Hour',
#  'Brik.Liam',
#  'The Britanys',
#  'BRONCHO',
#  'BRONCHO',
#  'BRONCHO',
#  'Brooke Annibale',
#  'Brooks Mosher b2b Submersible Machines',
#  'The Brother Brothers',
#  'Brother Sundance',
#  'Brownout',
#  'Bruno Belissimo',
#  'Bryann Trejo',
#  'Bubble Puppy',
#  'Buck Meek',
#  'Buddy',
#  'Buddy',
#  'Buddy',
#  'Buddy',
#  'Buddy Lofton',
#  'Buenos Diaz',
#  'Buffalo Blanco',
#  'BUHU',
#  'BUHU (DJ Set)',
#  'Built By Snow',
#  'Bully',
#  'Bully',
#  'Bun B',
#  'Bun B + Special Guests',
#  'The Buttertones',
#  'Buxton',
#  'The Bvtcher',
#  'Caamp',
#  'Caddywhompus',
#  'Cadence Weapon',
#  'Caitlyn Smith',
#  'Caitlyn Smith',
#  'Calan Mai',
#  'Caleb Caudle',
#  'Caleborate',
#  'Calliope Musicals',
#  'CALMLY',
#  'Calvin & Kimberly',
#  'Calvin Martyr',
#  'Cam',
#  'Candace',
#  'Candy West',
#  'Canon',
#  'Canshaker Pi',
#  'Canshaker Pi',
#  'The Canvas People',
#  'Cape Francis',
#  'CAPYAC',
#  'CAPYAC',
#  'CAPYAC (DJ Set)',
#  'Carlos Trevino (Austin, TX) vs Manuel Rubalacava (Mexico)',
#  'Carnage',
#  'Caroline Rose',
#  'Caroline Rose',
#  'Carson McHone',
#  'CASEROLOOPS',
#  'CASEROLOOPS',
#  'Casey Jay',
#  'Casper Skulls',
#  'Cassandra Jenkins',
#  'Cassandra Jenkins',
#  'Cassandra Robertson',
#  'Casual Strangers',
#  'Casual T',
#  'Catholic Action',
#  'Catholic Action',
#  "Catz 'N Dogz",
#  'Caught A Ghost',
#  'Cazzette',
#  'Cedric Burnside',
#  'Centavrvs',
#  'Centavrvs',
#  'Ceramic Animal',
#  'Ceramic Animal',
#  'Ceschi',
#  'Cha Cha Malone',
#  'Chadney Christle',
#  'Chagall',
#  'CHAI',
#  'CHAI',
#  'Chainska Brassika',
#  'The Chamanas',
#  "Champagne Superchillin'",
#  'Charles Fauna',
#  'Charlie Faye & The Fayettes',
#  'Charlie Faye & The Fayettes',
#  'Chaz-O',
#  'Che Lingo',
#  'Che Lingo',
#  'Che Lingo',
#  'Chelsea Williams',
#  'Chencha Berrinches',
#  'Cheryl Rivera',
#  'Cheryl Rivera',
#  'CHICKEN HILL',
#  'Chico Chico',
#  'ChihiroYamazaki+ROUTE14band',
#  'CHILLEMI',
#  'Chill Russell',
#  'Chinese Kitty',
#  'Chloe Foy',
#  'Chloe Foy',
#  'Chris Anthony',
#  'Chris Berardo',
#  'Chris Hicks',
#  'Chrissi Poland',
#  'Chris Stamey',
#  'Chris Stylez',
#  'Christaux',
#  'Christina Rosenvinge',
#  'Christopher Rees',
#  'Christy Hays',
#  'Chronophage',
#  'Chuck Auerbach',
#  'Churchwood',
#  'Cicada Rhythm',
#  'CIFIKA',
#  'CIFIKA',
#  'Cilantro Boombox',
#  'Cilantro Boombox',
#  'Cirkus Funk',
#  'Cirkus Funk',
#  'Cirque Noir [Live]',
#  'City Woods',
#  'C-Kan',
#  'C-Kan',
#  'CLARA',
#  'Clara Kent',
#  'CLARA-NOVA',
#  'Classixx',
#  'Classixx DJ Set',
#  'Classixx DJ Set',
#  'Clear Soul Forces',
#  'CLOVES',
#  'CLOVES',
#  'CLOVES',
#  'Club de Surf',
#  'Club de Surf',
#  'Club Night',
#  'Club Night',
#  'CMDWN',
#  'C-Micah',
#  'CMULA',
#  'COASTCITY',
#  'Cold Fronts',
#  'Cold War Kids',
#  'Colin Elmore & The Danville Train',
#  'Colin Gilmore',
#  'Colin Macleod',
#  'Colin Macleod',
#  'Collapsing Stars',
#  'Coma Pony',
#  'Coma Pony',
#  'Combo Chimbita',
#  'Combo Chimbita',
#  'The Commonheart',
#  'Common Holly',
#  'The Compozers',
#  'Cones',
#  'Cones',
#  'Cones',
#  'Confucius Jones',
#  'Cool Nutz',
#  'Cord Dibiase',
#  'Corduroi',
#  'Corner Boy P',
#  'Corridor',
#  'Corridor',
#  'Corridor',
#  'Cory Kendrix',
#  'Country Cousins',
#  'Count Vaseline',
#  'Courtney Farren',
#  'Courtney Marie Andrews',
#  'Courtney Marie Andrews',
#  'Courtney Marie Andrews',
#  'The Cowboys',
#  'Crayondroids',
#  'Creepside',
#  'Crespo',
#  'Crizzly',
#  'Crocodile Tears',
#  'Croosh',
#  'Croy and the Boys',
#  'Crumb',
#  'Crunk Witch',
#  'Crush',
#  'Cuban Doll',
#  'Cuban Doll',
#  'Cuco',
#  'Cuco',
#  'Cuddle Magic',
#  'Culture Wars',
#  'The Cunning',
#  'Cure For Paranoia',
#  'Currensy',
#  'Current Joys',
#  'Current Joys',
#  'Curtis McMurtry',
#  'Curtis Roush',
#  'Curtis Roush',
#  'Curved Light',
#  'Cut Chemist',
#  'Cut Chemist',
#  'Cut Copy',
#  'Cut Copy DJs',
#  'Cut Copy DJs',
#  'Cut Worms',
#  'Cut Worms',
#  'Cuyo',
#  'Cuz Lightyear',
#  'Cygnus',
#  'Da Chick',
#  'Da Church',
#  'Da Deacon',
#  'Daggy Man',
#  'Da Kid OC',
#  'Damar Jackson',
#  'Damien McFly',
#  'Dan Bettridge',
#  'Dan Bettridge',
#  'Dan Deacon',
#  'Danielle Grubb',
#  'DaniLeigh',
#  'Dan Lyons',
#  'Dan Lyons',
#  'Dante Elephante',
#  'Dan the Automator',
#  'Dany F',
#  'Dany F',
#  'Darkbird',
#  'Darkbird',
#  'Dark Time Sunshine',
#  'Dashboard Confessional',
#  'Dave East',
#  'Dave East',
#  'David Garza',
#  'David Gtronic',
#  'David Ramirez',
#  'DAVIE',
#  'Dawg Yawp',
#  'Dawn and Hawkes',
#  'Dax Mpire',
#  'Daylyt ',
#  'DAZION',
#  'DBando',
#  'Deadend Redd',
#  'Dead Horses',
#  'Dead Horses',
#  'The Dead South',
#  'The Dead South',
#  'Deanna Kouris',
#  'Deanna Wheeler',
#  'Dearly Beloved',
#  'Dearly Beloved',
#  'Dear Rouge',
#  'Death Bells',
#  'Death Bells',
#  'Death Hags',
#  'Death of a Dream',
#  'Deca',
#  'Decatur Redd',
#  'Decosi Fields',
#  'Dee-1',
#  'Dee Jay Silver',
#  'The Deer',
#  'Deer Vibes',
#  'Deezie Brown',
#  'Delorean',
#  'Deluxe',
#  'Deluxe',
#  'Deluxe',
#  'Demo Taped',
#  'Denis The Night & The Panic Party',
#  'Dennis Kalla',
#  'Dentist',
#  'Dentist',
#  'De Osos',
#  'Deraj',
#  'Derek Minor',
#  "Derez De'shon",
#  'Derian',
#  'Dermot Kennedy',
#  'Dermot Kennedy',
#  'Dermot Kennedy',
#  'Descartes A Kant',
#  'Descartes A Kant',
#  'Desi and Cody',
#  'Dessa',
#  'Dethgaze',
#  'DEVMO',
#  'Devon Gilfillian',
#  'Devras Plexi',
#  'Dezorah',
#  'DFZ',
#  'Dhruv Visvanath',
#  'Dice Soho',
#  'Dice Soho',
#  'Dice Soho',
#  'Dick Stusso',
#  'Didi',
#  'Didirri',
#  'The Digital Wild',
#  'DillanPonders',
#  'Dimpker Brothers',
#  'Dirty South Rydaz',
#  'Dirty Wormz',
#  'Disco Black',
#  'Distractor',
#  'Diverse Character',
#  'Divide And Dissolve',
#  'Dizzy',
#  'DJ Ace',
#  'DJ Ace',
#  'DJ Akuaa',
#  'Dj Anarchy',
#  'DJ Baby Roo',
#  'DJ Bar1ne',
#  'DJ Bubba',
#  'DJ C. DeVone',
#  'DJ Chip Banks',
#  'DJ Costa',
#  'DJ DB 405',
#  'DJ D-Lite',
#  'Dj Dmoney Global',
#  'DJ DOLLAR SENEGAL',
#  'Dj El Indio (World Hood Set)',
#  'DJ Enuff',
#  'DJ Grip',
#  'DJ Grip',
#  'DJ HALO',
#  'DJ Hella Yella',
#  'DJ Hella Yella',
#  'DJ Hella Yella',
#  'DJ Juls',
#  'DJ Kelly G',
#  'DJ KI',
#  'DJ King Mike',
#  'DJ Lil Zach',
#  'DJ Logan Garrett',
#  'Dj Luke Nasty',
#  'DJ Mix Master David',
#  'DJ Money',
#  'DJ Neptizzle',
#  'DJ Novela',
#  'DJ Osh Kosh',
#  'DJ Priddy Rickki',
#  'DJ Priddy Rickki',
#  'DJ Pumkin',
#  'DJ Ricky Silk',
#  'DJ RLE',
#  'DJ Rockwell',
#  'DJ ROCRYTE',
#  'DJ Rosegold',
#  'DJ Rosegold',
#  'DJ Ryan Wolf',
#  'DJ Ryan Wolf',
#  'DJ Ryan Wolf',
#  'DJ Soulseek',
#  'DJ Soulseek',
#  'DJ TradeMark',
#  'DJ unknown x CB5',
#  'DJ X.O.',
#  'DJ X.O.',
#  'DJ Zetroc b2b All Day Ray',
#  'DMC',
#  'DNA Music Group',
#  'DNA Music Group',
#  'Doc Daneeka',
#  'Doc Daneeka',
#  'Doc Daneeka',
#  'Doe',
#  'Doe',
#  'Doeman',
#  'Domico',
#  'Dominican Jay',
#  "Donae'O",
#  "Donae'O",
#  'Don Flamingo',
#  'Dontae',
#  'Doobie Powell',
#  'DopeKnife',
#  'Dorothy',
#  'Dot',
#  'Double Ferrari',
#  'Doughbeezy',
#  'Doughbeezy',
#  'Dox Black',
#  'DPR LIVE',
#  'Drab Majesty',
#  'Drama Diablo',
#  'Dramatic Lovers',
#  'Dray South',
#  'Dr. Bobby Banner, MPC',
#  "Dre' L.O.C.",
#  'Dre Prince',
#  'Dr. Joe',
#  'Dr. Octagon feat. DJ QBert & Dan the Automator',
#  'Dryspell',
#  'Dual Core',
#  'Dubfire',
#  'Duckwrth',
#  'Duckwrth',
#  'Duhrdy',
#  'Duncan Fellows',
#  'The Dunwells',
#  'Durand Jones & The Indications',
#  'DVWEZ',
#  'Dwagie',
#  'The Dwarves',
#  'D- Will',
#  'DYGL',
#  'DYGL',
#  'Dylan Cameron',
#  'Dylan Cameron',
#  'DYLN',
#  "Ed Schrader's Music Beat",
#  "Ed Schrader's Music Beat",
#  'Efek Rumah Kaca',
#  'Egrets On Ergot',
#  'Ehiorobo',
#  'Eimaral Sol',
#  'Elegante & La Imperial',
#  'Elegante & La Imperial',
#  'Elephant Stone',
#  'El Freaky',
#  'El Freaky',
#  'El Freaky',
#  'Eliot Lipp',
#  'Elise Trouw',
#  'Elle Exxe',
#  'Elle Exxe',
#  'Elle King',
#  'The Elliotts',
#  'Elohim',
#  'El Otro Grupo',
#  'El Otro Grupo',
#  'ELSZ',
#  'el Tambor de la Tribu',
#  'EMBRZ',
#  'Emerson Star',
#  'Emily Duff',
#  'Emily Wolfe',
#  'Emi Secrest',
#  'Emma Elisabeth',
#  'Emma Elisabeth',
#  'Emma White',
#  'Emme',
#  'Emme Woods',
#  'Ensign Broderick',
#  'Entropica',
#  'Entropica',
#  'Epic B',
#  'Eric Dingus',
#  'Erick Lottary',
#  'Erick Lottary',
#  'Eric Slick',
#  'Eric Tessmer',
#  'Eric Tessmer',
#  'Eric Tessmer',
#  'Erika Wennerstrom',
#  'Erva Carter',
#  'Eskiiimo',
#  'Essaie Pas',
#  'Estado de Sitio',
#  'Estado de Sitio',
#  'Ethan Kent',
#  'E-Turn',
#  'Eureka California',
#  'Evalyn',
#  'Ex-Girlfriends',
#  'Ex-Girlfriends',
#  'EZI',
#  'Ezra Collective',
#  'Ezra Furman',
#  'Ezra Furman',
#  'Fabrizio Cammarata',
#  'Fabrizio Cammarata',
#  'Facade HQ',
#  'FAIRE',
#  'FAIRE',
#  'Faith Healer',
#  'Faith Healer',
#  'Faiza',
#  'Famous 2 Most',
#  'The Fantastic Plastics',
#  'Farina',
#  'Farina',
#  'Farrows',
#  'Fastlane',
#  'Fatai',
#  'Fat Tony',
#  'Fat Tony',
#  'Faux Ferocious',
#  'FAVX',
#  'FAVX',
#  'Faye Webster',
#  'Faye Webster',
#  'Faze Miyake',
#  'FAZI',
#  'Febueder',
#  'Febueder',
#  'Febueder',
#  'FEDEL',
#  'Feid',
#  'Fenster',
#  'Fenster',
#  'Field Division',
#  'Field Report',
#  'Field Report',
#  'Field Report',
#  'Field Trip',
#  'FILIPE CATTO',
#  'Finale',
#  'Findlay',
#  'FINNEAS',
#  'Fishbach',
#  'Fishbach',
#  'The Fish Police',
#  'The Fish Police',
#  'Five 2 Oh',
#  'F L A C O',
#  'Flasher',
#  'FLAVIA',
#  'Floating Room',
#  'Flora Cash',
#  'Flora Cash',
#  'Flying Turns',
#  'Flyte',
#  'Flyte',
#  'Fntxy',
#  'Fntxy',
#  'Folk Family Revival',
#  'Folk Uke',
#  'The Fontaines',
#  'The Foreign Resort',
#  'Forever',
#  'Fort Never',
#  'FOXTRAX',
#  'FOXTRAX',
#  'Fragile Rock',
#  'Francine Thirteen',
#  'Francobollo',
#  'Francobollo',
#  'Frank McFly',
#  'Frank Turner',
#  'Frank Turner',
#  'Frank Turner',
#  'Frank Turner',
#  'Frank Waln',
#  'Freedom Fry',
#  'FREEWIFI',
#  'FREEWIFI',
#  'French Vanilla',
#  'French Vanilla',
#  'Frenchyy',
#  'The Frights',
#  'FRIGS',
#  'FRIGS',
#  'Friyie',
#  'Frontier Folk Nebraska',
#  'Fruit & Flowers',
#  'Fruit & Flowers',
#  'Fym Summer',
#  'Gabriel Wolfchild & The Northern Light',
#  'Gabylonia',
#  'GANGES',
#  'Gang of Youths',
#  'The Gary',
#  'Gatecreeper',
#  'Gato Preto',
#  'Gato Preto',
#  'Gaz Coombes',
#  'Gaz Coombes',
#  'Gemma Ray',
#  'Gemma Ray',
#  'Gemma Ray',
#  'Generation Now (DJ Drama, Don Cannon, Jack Harlow, Lil James, Killumanti)',
#  'Genesis Blu',
#  'Geno Cochino',
#  'George VonDoom',
#  'Gepe',
#  'Gepe',
#  'Germans',
#  'G Flip',
#  'G Flip',
#  'G Flip',
#  'GHETTO KIDS',
#  'GHETTO KIDS',
#  'Ghostland Observatory',
#  'Ghost Twin',
#  'Ghost Twin',
#  'The Ghost Wolves',
#  'A Giant Dog',
#  'Giant Kitty',
#  'Gigantor',
#  'Gina Chavez',
#  'Gina Sicilia',
#  'Girl Ray',
#  'Girl Ray',
#  'Girl Ray',
#  'GIRL SKIN',
#  'Girl Ultra',
#  'Girlyboi',
#  'G-Jet',
#  'Glassio',
#  'The Gloomies',
#  'Goat Girl',
#  'Goat Girl',
#  'Goat Girl',
#  'GO DJ JB',
#  'GO DJ JB',
#  'GO DJ JB',
#  'GoDJKnowledge & The Trendsetters',
#  'Go Fever',
#  'Go Fever',
#  'Gold Casio',
#  'Gold Casio',
#  'Golden Dawn Arkestra',
#  'Golden Dawn Arkestra',
#  'Golden Dawn Arkestra',
#  'Good Field',
#  'Gordi',
#  'Gordi',
#  'Gordi',
#  'Gothic Tropic',
#  'Gothic Tropic',
#  'GQ',
#  'Grace Joyner',
#  'Grace Vonderkuhn',
#  'Gracie and Rachel',
#  'Gracie and Rachel',
#  'Graham Reynolds',
#  'Graham Reynolds and the Golden Arm Trio',
#  'The Grahams',
#  'Grand Analog',
#  'Grand Analog',
#  'Grandchildren',
#  'Grand Rapids Soul Club',
#  'grav3y',
#  'Great Electric Quest',
#  'Great Good Fine Ok',
#  'Great Good Fine Ok',
#  'Great Good Fine Ok',
#  'Greenbeard',
#  'Greyhounds',
#  'Greyhounds',
#  'Greys',
#  'Greys',
#  'Grim Streaker',
#  'Grim Streaker',
#  'Grounders',
#  'Guantanamo Baywatch',
#  'Gulfer',
#  'Gus Dapperton',
#  'Gus Dapperton',
#  'Gus Dapperton',
#  'Guts Club',
#  'G Yamazawa',
#  'Haex',
#  'Hailey Tuck',
#  'Hajk',
#  'Hajk',
#  'Haley Heynderickx',
#  'Half Stack',
#  'Hans Gruber and the Die Hards',
#  'Harddrive',
#  'Hard Proof',
#  'Hardwork Movement',
#  'Hardy Caprio',
#  'Harmini',
#  'Harpooner',
#  'Harpooner',
#  'Harrison Lipton',
#  'Harry Edohoukwa',
#  'Harry Pane',
#  'Harry Zimm',
#  'Harvey McLaughlin',
#  'Hatchie',
#  'Hatchie',
#  'Hater',
#  'Hater',
#  'Hater',
#  'Haulm',
#  'Haunted Summer',
#  'Haux',
#  'Hayley Coupon',
#  'Hazey Eyes',
#  'The Heart Collectors',
#  'The Heart Collectors',
#  'The Hearts',
#  'The Heirs',
#  'HEKLER',
#  'Helena Deland',
#  'Helena Deland',
#  'Hembree',
#  'Hembree',
#  'Henry Brun & the Latin Playerz',
#  'Hety And Zambo',
#  'Hety And Zambo',
#  'HEX',
#  'HEX',
#  'The High Rollaz',
#  'High Waisted',
#  'Hilang Child',
#  'Himalayas',
#  ...]

# %%
for index, artist in enumerate(artist_list[1202:]):
        # print artist
        print 'artist: ', artist
        print 'index: ', index

        f = { 'src' : 'Kendrick Lamar', 'dest' : artist}
        # f = { 'src' : 'Kendrick Lamar', 'dest' : '1982'}
        url_encoded = urllib.urlencode(f)
        full_url = url + '?' + url_encoded
        # print full_url
        response = urllib.urlopen(full_url)
        if index == 20:
            break
        try:
            data = json.loads(response.read())
            raw_path = data['raw_path']
            artist_list_trimmed.append(artist)
        except KeyError as error:
            print 'no match from boilthefrog'
# Out:
# artist:  070
# index:  0
# artist:  16 the Olympus
# index:  1
# no match from boilthefrog
# artist:  1982 (diecinueve ochenta y dos)
# index:  2
# no match from boilthefrog
# artist:  1982 (diecinueve ochenta y dos)
# index:  3
# no match from boilthefrog
# artist:  1kPhew
# index:  4
# artist:  1Playy
# index:  5
# no match from boilthefrog
# artist:  20 Somethin' Band/Tenth Child Inc. House Band
# index:  6
# no match from boilthefrog
# artist:  24Hrs
# index:  7
# artist:  24Hrs
# index:  8
# artist:  3 Hand Stephen
# index:  9
# no match from boilthefrog
# artist:  5-D
# index:  10
# no match from boilthefrog
# artist:  5ive
# index:  11
# artist:  6Blocc
# index:  12
# no match from boilthefrog
# artist:  90 One
# index:  13
# no match from boilthefrog
# artist:  Abhi The Nomad
# index:  14
# artist:  Abisha Uhl
# index:  15
# no match from boilthefrog
# artist:  ABSTRACT
# index:  16
# artist:  ABSTRACT
# index:  17
# artist:  The Academic
# index:  18
# artist:  The Accidentals
# index:  19
# artist:  The Accidentals
# index:  20

# %%
print 'artist l', len(artist_list)
print 'artist l trimmed', len(artist_list_trimmed)
with open('artist_list_trimmed.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(alt_2)
# Out:
# artist l 2558
# artist l trimmed 489

# %%
artist_list_trimmed = artist_list_trimmed[:-10]

# %%
artist_list_trimmed
# Out:
# ['070',
#  '1kPhew',
#  '24Hrs',
#  '24Hrs',
#  '5ive',
#  'Abhi The Nomad',
#  'ABSTRACT',
#  'ABSTRACT',
#  'The Academic',
#  'The Accidentals',
#  'The Accidentals',
#  'A.CHAL',
#  'Action Bronson',
#  'Adam Torres',
#  'Adekunle Gold',
#  'Adekunle Gold',
#  'Adekunle Gold',
#  'Adrian Daniel',
#  'AHI',
#  'Aisha Badru',
#  'AJ',
#  'AJ Tracey',
#  'AJ Tracey',
#  'AKA',
#  'AKA',
#  'Albert Hammond Jr',
#  'Albert Hammond Jr',
#  'Aleman',
#  'Alex Rose',
#  'ALI AKA MIND',
#  'ALI AKA MIND',
#  'Alice Ivy',
#  'Alice Phoebe Lou',
#  'Alice Phoebe Lou',
#  'Allman Brown',
#  'Allman Brown',
#  'Alsarah & the Nubatones',
#  'Alsarah & the Nubatones',
#  'Amara La Negra',
#  'Amara La Negra',
#  'Amara La Negra',
#  'Amy Shark',
#  'Amy Shark',
#  'Andrew Applepie',
#  'Andrew Applepie',
#  'Andrew W.K.',
#  '...And You Will Know Us by the Trail of Dead',
#  'Angel',
#  'ANGELZ',
#  'Anna Burch',
#  'Anna Burch',
#  'Anna Wise',
#  'Anna Wise',
#  'Ant Beale',
#  'Ardalan',
#  'Ari',
#  'Arin Ray',
#  'Arin Ray',
#  'A-RON',
#  'Attractions',
#  'Audio Push',
#  'Audio Push',
#  'Avelino',
#  'AveParadiso',
#  'Bad Gyal',
#  'Bad Gyal',
#  'Bad Pony',
#  'Ball Greezy',
#  'Barachi',
#  'Barrie',
#  'Barrie',
#  'Bat Fangs',
#  'Bat Fangs',
#  'Bat Fangs',
#  'BAUM',
#  'BAUM',
#  'BbyMutha',
#  'Beach Slang',
#  'BeatKing',
#  'BeatKing',
#  'Becca Mancari',
#  'Belako',
#  'Benji Lewis',
#  'Benji Lewis',
#  'Ben Kweller',
#  'Beshken',
#  'B-Hi',
#  'Big T',
#  'Big Tobz',
#  'Big Zuu',
#  'Big Zuu',
#  'Billa',
#  'Billie Eilish',
#  'Billie Eilish',
#  'Billie Eilish',
#  'Billie Eilish',
#  'Billy Strings',
#  'B.I.P.',
#  'Bishop Briggs',
#  'The Bishops',
#  'Black Guayaba',
#  'Black Pistol Fire',
#  'Blake',
#  'Blessed',
#  'Blue Lab Beats',
#  'Bobo Swae',
#  'BODEGA',
#  'BODEGA',
#  'Bohemian Betyars',
#  'Bohemian Betyars',
#  'BONES (UK)',
#  'Boombox Cartel',
#  'Boy Harsher',
#  'BOYO',
#  'BP Valenzuela',
#  'Breakout',
#  'Brent Cowles',
#  'The Bright Light Social Hour',
#  'BRONCHO',
#  'BRONCHO',
#  'BRONCHO',
#  'Brooke Annibale',
#  'The Brother Brothers',
#  'Brother Sundance',
#  'Brownout',
#  'Bryann Trejo',
#  'Buddy',
#  'Buddy',
#  'Buddy',
#  'Buddy',
#  'Bully',
#  'Bully',
#  'Bun B',
#  'The Buttertones',
#  'Buxton',
#  'Caamp',
#  'Cadence Weapon',
#  'Caitlyn Smith',
#  'Caitlyn Smith',
#  'Caleborate',
#  'Cam',
#  'Canon',
#  'Cape Francis',
#  'CAPYAC',
#  'CAPYAC',
#  'Carnage',
#  'Caroline Rose',
#  'Caroline Rose',
#  'Catholic Action',
#  'Catholic Action',
#  "Catz 'N Dogz",
#  'Caught A Ghost',
#  'Cazzette',
#  'Centavrvs',
#  'Centavrvs',
#  'Ceramic Animal',
#  'Ceramic Animal',
#  'Ceschi',
#  'Chagall',
#  'CHAI',
#  'CHAI',
#  'The Chamanas',
#  'Che Lingo',
#  'Che Lingo',
#  'Che Lingo',
#  'Christina Rosenvinge',
#  'Cicada Rhythm',
#  'CIFIKA',
#  'CIFIKA',
#  'C-Kan',
#  'C-Kan',
#  'CLARA',
#  'Classixx',
#  'Clear Soul Forces',
#  'CLOVES',
#  'CLOVES',
#  'CLOVES',
#  'CMDWN',
#  'Cold War Kids',
#  'Coma Pony',
#  'Coma Pony',
#  'Common Holly',
#  'Corner Boy P',
#  'Courtney Marie Andrews',
#  'Courtney Marie Andrews',
#  'Courtney Marie Andrews',
#  'The Cowboys',
#  'Crespo',
#  'Crizzly',
#  'Croosh',
#  'Crumb',
#  'Crush',
#  'Cuban Doll',
#  'Cuban Doll',
#  'Cuco',
#  'Cuco',
#  'The Cunning',
#  'Currensy',
#  'Current Joys',
#  'Current Joys',
#  'Cut Chemist',
#  'Cut Chemist',
#  'Cut Copy',
#  'Cut Worms',
#  'Cut Worms',
#  'Cygnus',
#  'Da Chick',
#  'Daggy Man',
#  'Damar Jackson',
#  'Dan Deacon',
#  'DaniLeigh',
#  'Dan the Automator',
#  'Dark Time Sunshine',
#  'Dashboard Confessional',
#  'Dave East',
#  'Dave East',
#  'David Ramirez',
#  'DAVIE',
#  'Dawg Yawp',
#  'The Dead South',
#  'The Dead South',
#  'Dear Rouge',
#  'Deca',
#  'Dee-1',
#  'The Deer',
#  'Delorean',
#  'Deluxe',
#  'Deluxe',
#  'Deluxe',
#  'Demo Taped',
#  'Deraj',
#  'Derek Minor',
#  "Derez De'shon",
#  'Derian',
#  'Dermot Kennedy',
#  'Dermot Kennedy',
#  'Dermot Kennedy',
#  'Dessa',
#  'Dice Soho',
#  'Dice Soho',
#  'Dice Soho',
#  'Didi',
#  'Didirri',
#  'DillanPonders',
#  'Dirty Wormz',
#  'Dizzy',
#  'Dj Luke Nasty',
#  'DMC',
#  'Doc Daneeka',
#  'Doc Daneeka',
#  'Doc Daneeka',
#  'Doe',
#  'Doe',
#  'Domico',
#  "Donae'O",
#  "Donae'O",
#  'Dorothy',
#  'Dot',
#  'Doughbeezy',
#  'Doughbeezy',
#  'DPR LIVE',
#  'Drab Majesty',
#  'Dual Core',
#  'Dubfire',
#  'Duckwrth',
#  'Duckwrth',
#  'Duncan Fellows',
#  'The Dunwells',
#  'Durand Jones & The Indications',
#  'The Dwarves',
#  'DYGL',
#  'DYGL',
#  'Efek Rumah Kaca',
#  'Ehiorobo',
#  'El Freaky',
#  'El Freaky',
#  'El Freaky',
#  'Eliot Lipp',
#  'Elise Trouw',
#  'Elle King',
#  'Elohim',
#  'el Tambor de la Tribu',
#  'EMBRZ',
#  'Emily Wolfe',
#  'Essaie Pas',
#  'Evalyn',
#  'EZI',
#  'Ezra Collective',
#  'Ezra Furman',
#  'Ezra Furman',
#  'Faith Healer',
#  'Faith Healer',
#  'Farina',
#  'Farina',
#  'Fat Tony',
#  'Fat Tony',
#  'Faye Webster',
#  'Faye Webster',
#  'Faze Miyake',
#  'Febueder',
#  'Febueder',
#  'Febueder',
#  'FEDEL',
#  'Feid',
#  'Field Division',
#  'Field Report',
#  'Field Report',
#  'Field Report',
#  'FILIPE CATTO',
#  'Findlay',
#  'FINNEAS',
#  'Fishbach',
#  'Fishbach',
#  'F L A C O',
#  'FLAVIA',
#  'Flora Cash',
#  'Flora Cash',
#  'Flyte',
#  'Flyte',
#  'Fntxy',
#  'Fntxy',
#  'Forever',
#  'Francobollo',
#  'Francobollo',
#  'Frank Turner',
#  'Frank Turner',
#  'Frank Turner',
#  'Frank Turner',
#  'Freedom Fry',
#  'The Frights',
#  'Friyie',
#  'Gabylonia',
#  'GANGES',
#  'Gang of Youths',
#  'The Gary',
#  'Gatecreeper',
#  'Gaz Coombes',
#  'Gaz Coombes',
#  'Gepe',
#  'Gepe',
#  'GHETTO KIDS',
#  'GHETTO KIDS',
#  'Ghostland Observatory',
#  'A Giant Dog',
#  'Girl Ray',
#  'Girl Ray',
#  'Girl Ray',
#  'Girl Ultra',
#  'Girlyboi',
#  'Glassio',
#  'The Gloomies',
#  'Goat Girl',
#  'Goat Girl',
#  'Goat Girl',
#  'Gordi',
#  'Gordi',
#  'Gordi',
#  'Gothic Tropic',
#  'Gothic Tropic',
#  'GQ',
#  'Great Good Fine Ok',
#  'Great Good Fine Ok',
#  'Great Good Fine Ok',
#  'Greyhounds',
#  'Greyhounds',
#  'Greys',
#  'Greys',
#  'Guantanamo Baywatch',
#  'Gus Dapperton',
#  'Gus Dapperton',
#  'Gus Dapperton',
#  'G Yamazawa',
#  'Hailey Tuck',
#  'Hajk',
#  'Hajk',
#  'Haley Heynderickx',
#  'Hardy Caprio',
#  'Hatchie',
#  'Hatchie',
#  'Hater',
#  'Hater',
#  'Hater',
#  'Haux',
#  'Hazey Eyes',
#  'The Hearts',
#  'The Heirs',
#  'Helena Deland',
#  'Helena Deland',
#  'Hembree',
#  'Hembree',
#  'HEX',
#  'HEX',
#  'Himalayas',
#  'Himalayas',
#  'Hinds',
#  'Hinds',
#  'Hiss Golden Messenger',
#  'Holly',
#  'Holy Wave',
#  'Homeboy Sandman',
#  'Honduras',
#  'Honduras',
#  'Hop Along',
#  'Hopsteady',
#  'HorseShoe Gang',
#  'Hot Flash Heat Wave',
#  'Hovvdy',
#  'Hovvdy',
#  'Hundredth',
#  'Huxlee',
#  'HY$T',
#  'I Am Waiting For You Last Summer',
#  'I Am Waiting For You Last Summer',
#  'IDER',
#  'IDER',
#  'IDK',
#  'IDLES',
#  'IDLES',
#  'IDLES',
#  'I M U R',
#  'Injury Reserve',
#  'In The Valley Below',
#  'In The Valley Below',
#  'Isabel Davis',
#  'Ivy Sole',
#  'Izzie Gibbs',
#  'The Jacks',
#  'JadaL',
#  'JadaL',
#  'Jade Bird',
#  'Jade Bird',
#  'Jade Bird',
#  'Jaded',
#  'Jahmiel',
#  'Jahmiel',
#  'Jamie Grace',
#  'Janelle',
#  'Janiva Magness',
#  'Japandroids',
#  'Jared & the Mill',
#  'Jared & the Mill',
#  'Jarv Dee',
#  'Jasper Bones',
#  'JayDaYoungan',
#  'JayDaYoungan',
#  'Jaykae',
#  'Jay Park',
#  'Jay Park',
#  'Jay Prince',
#  'Jay Prince',
#  'Jeff Rosenstock',
#  'Jerry Williams',
#  'Jerry Williams',
#  'Jessie Reyez',
#  'Jhene Aiko',
#  'Joan Thiele',
#  'Joan Thiele',
#  'Joe Purdy',
#  'Joey Dosik',
#  'Joey Jewish',
#  'Joey Purp',
#  'Joey Purp',
#  'Johanna Warren',
#  'John Craigie',
#  'Jordan Rakei',
#  'Josh Rouse',
#  'Joshua Burnside',
#  'Josiah Bell',
#  'JPEGMAFIA',
#  'JPEGMAFIA',
#  'Juan Ingaramo',
#  'Juan Ingaramo',
#  'Jukebox the Ghost',
#  'Jukebox the Ghost',
#  'Junoflo',
#  'Junoflo',
#  'Kaki King',
#  'KAMAIYAH',
#  'Kane Brown']

# %%
alt_2 = artist_list_trimmed[:-10]

# %%
alt_2[-1]
# Out:
# 'Kane Brown'

# %%
artist_list[1200:1202]
# Out:
# ['Kamillion', 'Kane Brown']

# %%
artist_list[1202:]
# Out:
# ['KANGA',
#  'KannKasso',
#  'Kara Nichole-Robinson',
#  'KARD',
#  'Karol G',
#  'Karriem Riggins',
#  'Kat Graham',
#  'Kathryn Legendre',
#  'Katie von Schleicher',
#  'Kayla Freeman',
#  'Kay Odyssey',
#  'Kayper',
#  "K'Coneil",
#  "K'Coneil",
#  'Keedren Boston',
#  'Keith Urban',
#  'Kelela',
#  'Kelly Dean',
#  'Kelly Willis',
#  'Kelroy',
#  'Kelvyn Colt',
#  'Kemba',
#  'Kemba',
#  'Kenny Gee',
#  'Key Glock',
#  'Khalid',
#  'Khali Haat',
#  'Kids N Cats',
#  'Kiefer',
#  'Kiho',
#  'KILLY',
#  'KILLY',
#  'Kimmortal',
#  'Kimokal',
#  'Kim Petras',
#  'Kinda Super Disco',
#  'King Jamin b2b Scrooge Mcbuckz',
#  'King Pelican',
#  'Kings of the beach',
#  'Kings of the beach',
#  'King Tucka',
#  'Kino Kimino',
#  'Kitten',
#  'Kitten',
#  'Kitten',
#  'Kitty Cash',
#  'Kitty Cash',
#  'Knife in the Water',
#  'Knox Fortune',
#  'Kodie Shane',
#  'Kodie Shane',
#  'Kodie Shane',
#  'Kofi Black',
#  'Kojo Funds',
#  'Kojo Funds',
#  'Kojo Funds',
#  'KOLARS',
#  'KOLARS',
#  'Kollision',
#  'The Kominas',
#  'Konata Small',
#  'Kosha Dillz',
#  'Kosha Dillz',
#  'Kotomi',
#  'KP Tha Profit',
#  'KP Tha Profit',
#  'The Kraken Quartet',
#  'Kraus',
#  'Kraus',
#  'The Krickets',
#  'Kris Kasanova',
#  'Kristoff Krane',
#  'Krystal Klear',
#  'Kweku Collins',
#  'Kwesta',
#  'Kwesta',
#  'Kxng Crooked',
#  'Kydd Jones',
#  'Kyle Avallone',
#  'Kyle Craft',
#  'Kyle Craft',
#  'Kyle Dion',
#  'La Banda Morisca',
#  'LaBaq',
#  'LACHANE',
#  'La Etnnia',
#  'La Etnnia',
#  'La Fame',
#  'La Fame',
#  'La Fragua Band',
#  'La Fragua Band',
#  'La Fragua Band',
#  'The Lagoons',
#  'Lali Puna',
#  'Lali Puna',
#  'Lali Puna',
#  'La Luz',
#  'La Misa Negra',
#  'La Misa Negra',
#  'Lani Love',
#  'Lani Love',
#  'LANNDS',
#  'LAPS',
#  'Larkin Poe',
#  'Larkin Poe',
#  'Larry June',
#  'Larry Racer',
#  'Lauren Ashley and The Trainwreckers',
#  'Lauren Ruth Ward',
#  'Lauren Ruth Ward',
#  'Lawrence',
#  'LAX',
#  'League DJ JRO',
#  'Leather Girls',
#  'Le Couleur',
#  'Le Couleur',
#  'Lee Bains III + The Glory Fires',
#  'Lee Fields & The Expressions',
#  'Lee Hi',
#  'Le Galaxie',
#  'Leikeli47',
#  'Leikeli47',
#  'The Lemons',
#  'Le Naturel',
#  'Leni Stern',
#  'Leoncarlo',
#  'Leon Of Athens',
#  'Lethal Injektion',
#  'Letta J',
#  'Lettermen Project',
#  'Levon',
#  'Lex Empress',
#  'Lexii Alijai',
#  'Lexx Sequoia',
#  'Ley Line',
#  'Leyya',
#  'Lido Pimienta',
#  'Lido Pimienta',
#  'Lido Pimienta',
#  'Lido Pimienta',
#  'Lido Pimienta',
#  'LIFE',
#  'LIFE',
#  'LIFE',
#  'Lil Boii Kantu',
#  'Lil Freaky aka Dripset Freaky',
#  'Lil Gnar',
#  'Lil Gnar',
#  'Lime Cordiale',
#  'Lime Cordiale',
#  'Lime Cordiale',
#  'Lincoln Foley Schofield',
#  'Linda Lee',
#  'Linda Lee',
#  'Linda Perry',
#  'Lindsey Mills',
#  'Line Upon Line Percussion',
#  'Lingua Franca',
#  'Liniker e os Caramelows',
#  'Liniker e os Caramelows',
#  'Lion',
#  'Lion Babe',
#  'Lions Ambition',
#  'LIP',
#  'Lisa Heller',
#  'Lisa LeBlanc',
#  'Lisa LeBlanc',
#  'Lisa LeBlanc',
#  'Lisa Morales',
#  'Little Bacon Bear',
#  'Little Destroyer',
#  'Little Destroyer',
#  'littleDNGR',
#  'Living Hour',
#  'Livingmore',
#  'The Living Museum',
#  'Liza Anne',
#  'Liza Anne',
#  'Liz Brasher',
#  'Liz Brasher',
#  'Liz Cooper and the Stampede',
#  'Lizzie and The Makers',
#  'Lizzie No',
#  'LNDN DRGS/Jay Worthy',
#  'LNG/SHT',
#  'LNG/SHT',
#  'LNG/SHT',
#  'Lo Country',
#  'Loki',
#  'LOLA Local Opera Local Artists',
#  'Lola Marsh',
#  'Lola Marsh',
#  'Lola Marsh',
#  'Lola Tried',
#  'Lola Tried',
#  'Lola Tried',
#  'Lolo Lovina',
#  'Lolo Lovina',
#  'Lomelda',
#  'Lomelda',
#  'Lomelda',
#  'Lo Moon',
#  'Lo Moon',
#  'London Reyes',
#  'Look Vibrant',
#  'L/O/O/N',
#  'Lord Buffalo',
#  'Lorine Chia',
#  'Los Chinchillos Del Caribe',
#  'Los Chinchillos Del Caribe',
#  'Los Chinchillos Del Caribe',
#  'Los Coast',
#  'Los Coast',
#  'Los Coast',
#  'Los Lobos',
#  'Los Outsaiders',
#  'Los Outsaiders',
#  'Los Profetas',
#  'Los Skarnales',
#  'The Lost Brothers',
#  'The Lost Brothers',
#  'Los Wilds',
#  'Los Wilds',
#  'Loud Luxury',
#  'Louis Futon DJ Set',
#  'Louis Futon LIVE',
#  'Lou Rebecca',
#  'lovelytheband',
#  'lovelytheband',
#  'Love Moor',
#  'Love You Later',
#  'Low',
#  'Low',
#  'Low Cut Connie',
#  'Low Cut Connie',
#  'Low Cut Connie',
#  'LPX',
#  'Lucette',
#  'Lucia',
#  'Lucky Loc',
#  'Lucy Dacus',
#  'Lucy Dacus',
#  'Lucy Rose',
#  'Lucy Spraggan',
#  'Ludo',
#  'LUFO',
#  'Lukas Nelson and Promise of the Real',
#  'The Lulls',
#  'Luna Lee',
#  'Luna Lee',
#  'Lung',
#  'LuxDeluxe',
#  'LuxDeluxe',
#  'Luz Pinos',
#  'The Lvrds',
#  'LYLO',
#  'LYLO',
#  'Lyons & Co.',
#  'Lyric Michelle',
#  'M3CCA',
#  'Mackinazz Magilla',
#  'MADDEE',
#  'Madison McFerrin',
#  'Madison McFerrin',
#  'Mad Mexicans',
#  'M A E S T R O',
#  'Magic Bronson',
#  'Magna Carda',
#  'The Magnettes',
#  'MainMain',
#  'Majestic Casual DJs',
#  'Majestic Casual DJs',
#  'Makana',
#  'Mala Bengala',
#  'Mala Bengala',
#  'Mal Blum and The Blums',
#  'Mal Blum and The Blums',
#  'Mallrat',
#  'Mallrat',
#  'Mal & Quill',
#  'Mama Duke',
#  'MANEKA',
#  'Manny Mondragon (Austin, TX) vs Tyler Pacheco (Tyler, TX)',
#  'Mannywellz',
#  'Many Rooms',
#  'Many Rooms',
#  'M.A.R. ',
#  'Marco McKinnis',
#  'Marc Scibilia',
#  'Margaret Chavez',
#  'Marlo',
#  'Marlon Williams',
#  'Marlon Williams',
#  'Marlon Williams',
#  'Marshmallow Coast',
#  'Mary Ocher',
#  'Masha',
#  'Masha',
#  'Mason Flynt',
#  'Mathias.',
#  'Matt Costa',
#  'Matt Costa',
#  'Mattiel',
#  'Mattiel',
#  'Mau Mau Chaplains',
#  'Mauno',
#  'MAX',
#  'Max Meser',
#  'Maxo Kream',
#  'Maxo Kream',
#  'Max Richter',
#  'Mayah Dyson',
#  'MC Frontalot',
#  'Meanswell',
#  'Medicine Man Revival',
#  'The Medium',
#  'Megan Thee Stallion',
#  'Mega Ran',
#  'Mejor Actor De Reparto',
#  'Mejor Actor De Reparto',
#  'Mekhrubon Sanginov (Tajikistan) vs TBD',
#  'Melenas',
#  'Melenas',
#  'Melenas',
#  'Melo Makes Music',
#  'Melymel',
#  'Melymel',
#  'Memories In Broken Glass',
#  'Men I Trust',
#  'Men I Trust',
#  'METZ',
#  'MEUTE',
#  'MEUTE',
#  'MEUTE',
#  'MEUTE',
#  'MICHAEL 5000 WATTS',
#  'Michael Coronado (San Marcos, TX) vs Ali Bayolev (Kazakhstan)',
#  'Michael Rault',
#  'Micki Miller',
#  'Mic Taylor',
#  'MIDDLESPOON',
#  'Migrant Kids',
#  'Miguel',
#  'Mika Shinno',
#  'Mike Gz',
#  'MIKNNA',
#  'MIKNNA',
#  'Miles Francis',
#  'Milk & Bone',
#  'Milk & Bone',
#  'Milk & Bone',
#  'Millyz',
#  'Mimicking Birds',
#  'MINT FIELD',
#  'MINT FIELD',
#  'MINT FIELD',
#  'Miqui Brightside DJ Set',
#  'Mir Fontane',
#  'Mir Fontane',
#  'Miss Eaves',
#  'Missions',
#  'Miss Krystle',
#  'Miss Lavelle White and the L Men',
#  'Missy D',
#  'mluna',
#  'Mndsgn',
#  'Mndsgn',
#  'MNKYBSNSS',
#  'MNKYBSNSS',
#  'Mo3',
#  'Moaning',
#  'Moaning',
#  'Mobley',
#  'Moira Mack',
#  'Mokoomba',
#  'Mokoomba',
#  'Molly Brazy',
#  'Molly Brazy',
#  'Molly Brazy',
#  'Molly Burch',
#  'Mondragon',
#  'Money Chicha',
#  'The Money War',
#  'The Money War',
#  'The Money War',
#  'MONOGEM',
#  'Monoloc',
#  'Monoplasma',
#  'Monoplasma',
#  'Montell Fish',
#  'Monte Warden and The Dangerous Few',
#  'Montie Blaze',
#  'Moodie Black',
#  'Moonlight Breakfast',
#  'Moonrise Nation',
#  'Moonshine',
#  'Moonshine',
#  'Moon Taxi',
#  'Moonwalks',
#  'Morgan Saint',
#  'Morgan Saint',
#  'Morgan Saint',
#  'morgxn',
#  'Moses Boyd - Solo X',
#  'Moses Boyd - Solo X',
#  'Mosie',
#  'Motel Mirrors',
#  'Motel Raphael',
#  'Mother Falcon',
#  'Mothership',
#  'Motorcade',
#  'Mountain Time',
#  'The Movement',
#  'Moving Panoramas',
#  'Moxizishi & Jikehabu & 3He Project',
#  'Mozart La Para',
#  'Mozes and the Firstborn',
#  'Mozes and the Firstborn',
#  'MPR Riche Rich',
#  'Mr. Frankie Wilson',
#  'M. Rivers',
#  'Mr.Kitty',
#  'Mr. Lewis and The Funeral 5',
#  'Mr. Paradise',
#  'Mr. Paradise',
#  'Mr Wired Up',
#  'Mt. Joy',
#  'Mt. Joy',
#  'Mu Dills',
#  'Murda Beatz',
#  'Murda Beatz',
#  'Museless',
#  'Museless',
#  'Muther',
#  'MXMS',
#  'My Education',
#  'MY!GAY!HUSBAND! (DJ Between Sets)',
#  'Naaz',
#  'Nailah Blackman',
#  'Naked Giants',
#  'Naked Giants',
#  'The Naked Tungs',
#  'Nakury',
#  'Nakury',
#  'Nancy Whang',
#  'Nani Castle',
#  'Nassau',
#  'Natalie Prass',
#  'Natalie Prass',
#  'Natalie Prass',
#  'Nathaniel Rateliff & The Night Sweats',
#  'Nathaniel Rateliff & The Night Sweats',
#  'The National Reserve',
#  'Navelle Hice',
#  'Navy Gangs',
#  'Nea Agostini',
#  'Nea Agostini',
#  'The Neal Pollack Quintet',
#  'Neila ',
#  'Neil Frances',
#  'Neil Frances',
#  'Neil Frances',
#  'Nems',
#  'Ness Nite',
#  'Neuman',
#  'New Fame',
#  'NHD - Nourallah Harvey Dezen',
#  'Nick Wayne',
#  'Niena Drake',
#  'Night Beats',
#  'Night Beats',
#  'Night Drive',
#  'Night Moves',
#  'The Nightowls',
#  'The Nightowls',
#  'Nike Boi',
#  'Niki Ellis',
#  'Nikki Lane',
#  'Nikki Lane',
#  'The Nimbus',
#  'Nina Nesbitt',
#  'Nina Nesbitt',
#  'NITE',
#  'Nitti Gritti',
#  'NIX',
#  'NIX',
#  'Nnamdi Ogbonnaya',
#  'Nnamdi Ogbonnaya',
#  'Nnamdi Ogbonnaya',
#  'Noah Cyrus',
#  'Noah Cyrus',
#  'Noah Slee',
#  'Noah Slee',
#  'Noah Slee',
#  'nobigdyl.',
#  'NOBUNNY',
#  'NoMBe',
#  'NoMBe',
#  'Non Canon',
#  'Noochie',
#  'NOOK Turner',
#  'No Parents',
#  'Not3s',
#  'Not3s',
#  'Not3s',
#  'nothing,nowhere.',
#  'No Vacation',
#  'No Vacation',
#  'No Vacation',
#  'No Weapon',
#  'NO WIN',
#  'Now, Now',
#  'Now, Now',
#  'NOX BOYS',
#  'Nubya Garcia',
#  'The Nude Party',
#  'NUE',
#  'Numb.er',
#  'Numb.er',
#  'NVDES',
#  'NVDES',
#  'NY Night Train Soul Clap & Dance Off + Special Guests',
#  'Oak House',
#  'The Octanes',
#  'The Octopus Project',
#  'Odalys Pena',
#  'Odalys Pena',
#  'Odetta Hartman',
#  'Off The Dome',
#  'OG Maco',
#  'OG Ron C & The Chopstars',
#  'OHMME',
#  'Oh My Love',
#  'Oh, Rose',
#  'Okey Dokey',
#  'Okkervil River',
#  'Okkervil River',
#  'Okkervil River',
#  'Old Crow Medicine Show',
#  'Oliver Rajamani',
#  'Oliver Riot',
#  'Olivia Noelle',
#  'OMB Bloodbath',
#  'Omenihu',
#  'Omni',
#  'Omni',
#  'OnBeatMusic',
#  'Only Girl',
#  'Only Girl',
#  'Orange Calderon',
#  'Oran Juice Jones ii',
#  'ORB',
#  'ORB',
#  'ORB',
#  'Ori Dagan',
#  'Oscar Black',
#  'OSHUN',
#  'OSHUN',
#  'Otis the Destroyer',
#  'Otzeki',
#  'Otzeki',
#  'Ought',
#  'Ought',
#  'Our Girl',
#  'Our Girl',
#  'The Outer Vibe',
#  'The Outer Vibe',
#  'The Outfit, TX',
#  'Overlake',
#  'Overlake',
#  'OY',
#  'OY',
#  'OY',
#  'Pale Waves',
#  'Pale Waves',
#  'Palm',
#  'Palo Duro',
#  'Panic Priest',
#  'Papachina',
#  'Papachina',
#  'Papisa',
#  'Pardoner',
#  'Parker Millsap',
#  'Parrot Dream',
#  'Parsonsfield',
#  'Particle Devotion',
#  'Partner',
#  'Partner',
#  'Part Time',
#  'Party Boi Rok',
#  'Party Pupils',
#  'Party Pupils',
#  'Party Pupils',
#  'Passeport',
#  'PASTEL GHOST',
#  'Pat Lok',
#  'Patoranking',
#  'Patrick Sweany',
#  'Paul Benjaman Band',
#  'Paul Cauthen',
#  'Paul McDonald',
#  'Peach Pit',
#  'Peach Pit',
#  'Peanut Butter Wolf',
#  'Pearl Charles',
#  'Pearl Earl',
#  'Pedro Menendez Fusion Ensemble',
#  'Peelander-Z',
#  'Penguin Prison',
#  'Pepe Mogt ( Nortec)',
#  'Peso Da Mafia',
#  'Peso Da Mafia',
#  'Peterson Brothers',
#  'Peyton',
#  'pH-1',
#  'Phase One',
#  'Phe Reds',
#  'Philharmonik',
#  'Picture My Vision Entertainment',
#  'Pierre Kwenders',
#  'Pierre Kwenders',
#  'Pierre Kwenders',
#  'Pike and Sutton',
#  'Pink Mexico',
#  'Pixel Grip',
#  'Pixel Terror',
#  'PJ Morton',
#  'Pkew Pkew Pkew',
#  'Pkew Pkew Pkew',
#  'A Place to Bury Strangers',
#  'A Place to Bury Strangers',
#  'A Place to Bury Strangers',
#  'Plain James',
#  'Planet Booty',
#  'Plastic Picnic',
#  'Plastic Pinks',
#  'P Montana',
#  'P Montana',
#  'Pneuma',
#  'Pneuma',
#  'PoeTeK',
#  'Pommez Internacional',
#  'Pommez Internacional',
#  'Ponytrap',
#  'Poppies',
#  'Popstitute',
#  'Popstitute',
#  'Porcelan',
#  'Porches',
#  'Post Animal',
#  'Post Animal',
#  'Powers Pleasant',
#  'Powers Pleasant',
#  'Powers Pleasant',
#  'Pow Pow Family Band',
#  'Prairie WWWW',
#  'PRANKROOM',
#  'Preservation Hall Jazz Band',
#  'The President Lincoln',
#  'Pretty City',
#  'Pretty City',
#  'Primo',
#  'prince chaRLEZ',
#  'Princess Nokia',
#  'Prinz Grizzley and his Beargaroos',
#  'Prisco Marquez (Austin, TX) vs Tanner Dodd (Waco, TX)',
#  'Private Club Records',
#  'Private School',
#  'Private School',
#  'Promise',
#  'Promiseland',
#  'pronoun',
#  'Propaganda',
#  'PROPAIN',
#  'Prophet',
#  'Public Access T.V.',
#  'Public Access T.V.',
#  'Pujol',
#  'Punjabtronix',
#  'Punjabtronix',
#  'Pure Powers',
#  'Pussy Riot',
#  'Pussy Riot',
#  'Qais Essar',
#  'Q. Guyton',
#  'Q Money',
#  'The Qualitons',
#  'Quantum Split',
#  'Queen of Jeans',
#  'Quiet Kids',
#  'Quiet Slang',
#  'Quincey White',
#  'Quin NFN',
#  'Quin NFN',
#  'Quinn Lewis',
#  'Quique Escamilla',
#  'Rachel K Collier',
#  'Rachel K Collier',
#  'Rachel Mason',
#  'Rackajam',
#  'Radio Galaxy',
#  'Ramesh',
#  'Ramesh',
#  'Range Emotion',
#  'Range Emotion',
#  'Rapsody',
#  'Rapsody',
#  'Rapsody',
#  'Ratboys',
#  'Rat Fancy',
#  'Rattletree',
#  'Rawayana',
#  'R.A.W. (READY AND WILLING)',
#  'Raye Zaragoza',
#  'Ray Fuego',
#  'Ray Fuego',
#  'Rayland Baxter',
#  'Rayland Baxter',
#  'Raymix',
#  'Ray Wylie Hubbard',
#  'Raz Simone',
#  'Rebecca Loebe',
#  'Red Dirt Rangers',
#  'Redd Volkaert',
#  'Red Shahan',
#  'Reeves Gabrels & His Imaginary Friends',
#  'Rehab',
#  'Remember Sports',
#  'Remna Schwarz',
#  'Renata Zeiguer',
#  '*repeat repeat',
#  '*repeat repeat',
#  'The Reputations',
#  'Residual Kid',
#  'The Resonars',
#  'Reuben Bidez',
#  'Revolver Plateado',
#  'Revolver Plateado',
#  'Rev. Sekou',
#  'Rexx Life Raj',
#  'Rhys Lewis',
#  'Rhys Lewis',
#  'Rich Mutts',
#  'Richy Hyliger',
#  'Ricky Rebel',
#  'Rico Davis',
#  'Rico Nasty',
#  'Rico Nasty',
#  'Riders Against the Storm',
#  'Riders Against the Storm',
#  'Riders Against the Storm',
#  'Riff3x',
#  'Ringo Deathstarr',
#  'Ripdee',
#  "The Risin' Sun",
#  'Rita Coolidge',
#  'RJ Comer',
#  'R.LUM.R.',
#  'R.LUM.R.',
#  'RMBLR',
#  'Rob Gullatte',
#  'Rob Stone',
#  'Rock Boy Fresh',
#  'Rockstar Jt',
#  'Rocky Banks',
#  'Rocky Banks',
#  'Rod Melancon',
#  'Roi Perez',
#  'Roky Erickson',
#  'Rome Is Not A Town',
#  'Ron Gallo',
#  'Ronnie Heart',
#  'The Roots',
#  'Rosemary & Garlic',
#  'Rosemary & Garlic',
#  'Rosie Flores',
#  'Roxy Roca',
#  'Royal Forest',
#  'The RPMs',
#  'The RPMs',
#  'The Rubilators',
#  'Ruby Boots',
#  'Ruby Haunt',
#  'Ruby Ibarra',
#  'Rude Kid',
#  'Runway Richy',
#  'Ruslan',
#  'RVG',
#  'RVG',
#  'Ryan Brahms',
#  'Ryan Culwell',
#  'RYAN Playground',
#  'RZA of Wu-Tang Clan feat. Stone Mecca',
#  'Sad Baxter',
#  'SadGirl',
#  'Sahad and The Nataal Patchwork',
#  'Said The Whale',
#  'Sailor Poon',
#  'Saint Sister',
#  'Saint Sister',
#  'Saint Sister',
#  "Salem's Bend",
#  'Salt Cathedral',
#  'Salt Cathedral',
#  'Samantha Glass',
#  'Sam Fender',
#  'Sam Fender',
#  'Sam Fender',
#  'Sam Himself',
#  'Sam Morrow',
#  'Sam Morrow',
#  'Sammus',
#  'Sammus',
#  'Sammus',
#  'Sampson',
#  'Sampson',
#  'Samurai Champs',
#  'Samurai Champs',
#  'Sandovall',
#  'Sangat!',
#  'Sangpuy',
#  'SANTIAGO',
#  'Sarah Klang',
#  'Sarah Shook & The Disarmers',
#  'Sarah Shook & The Disarmers',
#  'Sara Ontaneda',
#  'Sara Ontaneda',
#  'sarasara',
#  'sarasara',
#  'Sass',
#  'Sassy 009',
#  'Sassy 009',
#  'SassyBlack',
#  'Savak',
#  'Saweetie',
#  'Saweetie',
#  'Say Anything',
#  'Say Sue Me',
#  'Say Sue Me',
#  'Say Sue Me',
#  'Scenic Route to Alaska',
#  'Scenic Route to Alaska',
#  'Schaffer the Darklord',
#  'Scott Collins',
#  'Sea Moya',
#  'Sean C. Johnson',
#  'Sean Leon',
#  'Sean Leon',
#  'Season to Risk',
#  'Second Hand Rose',
#  'Secret Sands',
#  'Sego',
#  'Seis Pistos',
#  'SEND MEDICINE',
#  'SERTIFIED',
#  'SETI X',
#  'Seyi Shay',
#  'Seyi Shay',
#  'The Shacks',
#  'The Shacks',
#  'Shakey Graves',
#  'Shame',
#  'Shame',
#  'Shame',
#  'Shamir',
#  'SHAO',
#  'Sharkmuffin',
#  'Sharkweek',
#  'Sharlene',
#  'Shelita Burke',
#  'Shell of a Shell',
#  'Sherwood Marty',
#  'Sherwood Marty',
#  'She Sir',
#  'Shetler Jones',
#  'Shinyribs',
#  'ShitKid',
#  'ShitKid',
#  'Shope',
#  'Shopping',
#  'Shopping',
#  'Shred Kelly',
#  'Shubzilla x Bill Beats',
#  'Shy Beast',
#  'Shy Speaks',
#  'Sian Anderson',
#  'Sie Lieben Maschinen',
#  'Siimba Liives Long/Haile Supreme',
#  'Sikwitit',
#  'Silibrina',
#  'SILVASTONE',
#  'SILVASTONE',
#  'Simen Sez',
#  'Simon Grossmann',
#  'Simon Grossmann',
#  'Single Lash',
#  'The Sisterhood Band',
#  'SISTERS',
#  'Sixo',
#  'Skanks Roots Project',
#  'Skinny Lister',
#  'Skooly',
#  'Skratch Bastid',
#  'Skyway Man',
#  'slenderbodies',
#  'slenderbodies',
#  'Sloppy Jane',
#  'Sloppy Jane',
#  'The Sloths',
#  'Slow Caves',
#  'Slum Sociable',
#  'Slum Sociable',
#  'Small Houses',
#  'Small Island Big Song',
#  'Small Island Big Song',
#  'Smino',
#  'Smokepurpp',
#  'Smokepurpp',
#  'Smokepurpp',
#  'Smokey Brights',
#  'Snail Mail',
#  'Snail Mail',
#  'Snap Dogg',
#  'Sneaks',
#  'Sneaks',
#  'SOB X RBE',
#  'Soccer Mommy',
#  'Soda Lilies',
#  'Soia',
#  'Some Kind of Animal',
#  'Some Kind of Animal',
#  'Son Fjord B2B Daetron Vargas',
#  'Sonia Calico',
#  'Son Little',
#  'Sonny Bonoho',
#  'SonReal',
#  'Sons of an Illustrious Father',
#  'Sons of an Illustrious Father',
#  'Sons Of The East',
#  'SORNE',
#  'SoulGroupUniverse',
#  'SoundMass',
#  'Southern Avenue',
#  'Soviet',
#  'Soweto Kinch',
#  'Soweto Kinch',
#  'Spaceboifresh',
#  'Special Explosion',
#  'Special Explosion',
#  'Special Guest',
#  'Special Guest',
#  'Special Guest',
#  'Special Guest ',
#  'Speedy Ortiz',
#  'Spendtime Palace',
#  'Spirit Adrift',
#  'Spirit In The Room',
#  'spirit of the beehive',
#  'SpivOberta',
#  'Sports',
#  'Sputnik',
#  'Sputnik',
#  'SpzZy Turnt',
#  'Squidnice',
#  'Squidnice',
#  'STAL',
#  'Starcrawler',
#  'Starcrawler',
#  'Starcrawler',
#  'Statik selektah',
#  'Steak',
#  'Steelyone',
#  'Stefficrown',
#  'Stefficrown',
#  'Stefficrown',
#  'Stella Donnelly',
#  'Stella Donnelly',
#  'The Steoples',
#  'Stephanie Rice',
#  'Stephen Mykal & Feng Shway',
#  'Step Rockets',
#  'Stev Camo',
#  'Steve Hauschildt',
#  'Stimulator Jones',
#  'STLNDRMS',
#  'Stone Wheels',
#  'Stop Light Observations',
#  'Stove',
#  'Strange Love',
#  'Strawberry Runners',
#  'Street Hymns',
#  'Strvngers',
#  'The Strypes',
#  'The Strypes',
#  'Sturle Dagsland',
#  'Stuyedeyed',
#  'Subhi',
#  'Subs',
#  'Suburban Living',
#  'Sudan Archives',
#  ...]
